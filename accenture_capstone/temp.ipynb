# %%
from tavily import TavilyClient
from langchain_ollama import ChatOllama

# %%
TAVILY_API_KEY = "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"

# %%
client = TavilyClient(api_key=TAVILY_API_KEY)
response = client.search(query="What is the capital of India?", search_depth="advanced")

# %%
response
# Out:
# {'query': 'What is the capital of India?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://www.usatoday.com/story/news/world/2023/05/24/what-is-the-capital-of-india/70195720007',
#    'title': 'What is the capital of India? States and union territories explained. - USA Today',
# ...

# %%
for result in response["results"]:
    print(f"Title: {result['title']}")
    print(f"URL: {result['url']}")
    print(f"Snippet length: {len(result['content'])}")
    print("-" * 40)
# Out:
# Title: What is the capital of India? States and union territories explained. - USA Today
# URL: https://www.usatoday.com/story/news/world/2023/05/24/what-is-the-capital-of-india/70195720007
# Snippet length: 1655
# ----------------------------------------
# Title: What is the capital city of India? - Facebook
# URL: https://www.facebook.com/groups/996470140768323/posts/1936439506771377
# Snippet length: 143
# ----------------------------------------
# Title: List of capitals of India
# URL: https://en.wikipedia.org/wiki/List_of_capitals_of_India
# Snippet length: 6362
# ----------------------------------------
# Title: List of cities that served as the capital of India | India News - Times of India
# URL: https://timesofindia.indiatimes.com/india/list-of-cities-that-served-as-the-capital-of-india/articleshow/111815680.cms
# Snippet length: 4423
# ----------------------------------------
# Title: India’s Capital City: Should We Call It Delhi or New Delhi? – The Diplomat
# ...
